# %%
import pandas as pd
import numpy as np
import datetime as dt
# !pip install openpyxl
# Out:
# ...
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/250.0 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/250.0 kB 325.1 kB/s eta 0:00:01
#      ----------------- ------------------ 122.9/250.0 kB 901.1 kB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 1.4 MB/s eta 0:00:00
# ...

# %%
file = r'C:\Users\김동민\Desktop\datasets\airpollution\AirPollutionSeoul\Measurement_summary.csv'
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Measurement date  Station code  \
# 0  2017-01-01 00:00           101
# 1  2017-01-01 01:00           101
# 2  2017-01-01 02:00           101
# 3  2017-01-01 03:00           101
# 4  2017-01-01 04:00           101
#
#                                              Address   Latitude   Longitude  \
# 0  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 1  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 2  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 3  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 4  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
#
#      SO2    NO2     O3   CO  PM10  PM2.5
# 0  0.004  0.059  0.002  1.2  73.0   57.0
# 1  0.004  0.058  0.002  1.2  71.0   59.0
# 2  0.004  0.056  0.002  1.2  70.0   59.0
# 3  0.004  0.056  0.002  1.2  70.0   58.0
# 4  0.003  0.051  0.002  1.2  69.0   61.0

# %%
df.describe()
# Out:
#         Station code       Latitude      Longitude            SO2  \
# count  647511.000000  647511.000000  647511.000000  647511.000000
# mean      113.000221      37.553484     126.989340      -0.001795
# std         7.211315       0.053273       0.078790       0.078832
# min       101.000000      37.452357     126.835151      -1.000000
# 25%       107.000000      37.517528     126.927102       0.003000
# 50%       113.000000      37.544962     127.004850       0.004000
# 75%       119.000000      37.584848     127.047470       0.005000
# max       125.000000      37.658774     127.136792       3.736000
#
#                  NO2             O3             CO           PM10  \
# count  647511.000000  647511.000000  647511.000000  647511.000000
# mean        0.022519       0.017979       0.509197      43.708051
# std         0.115153       0.099308       0.405319      71.137342
# min        -1.000000      -1.000000      -1.000000      -1.000000
# ...

# %%
df.shape
# Out:
# (647511, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647511 entries, 0 to 647510
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Measurement date  647511 non-null  object
#  1   Station code      647511 non-null  int64
#  2   Address           647511 non-null  object
#  3   Latitude          647511 non-null  float64
#  4   Longitude         647511 non-null  float64
#  5   SO2               647511 non-null  float64
#  6   NO2               647511 non-null  float64
#  7   O3                647511 non-null  float64
#  8   CO                647511 non-null  float64
#  9   PM10              647511 non-null  float64
#  10  PM2.5             647511 non-null  float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 54.3+ MB

# %%
df['Measurement date'] = pd.to_datetime(df['Measurement date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647511 entries, 0 to 647510
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Measurement date  647511 non-null  datetime64[ns]
#  1   Station code      647511 non-null  int64
#  2   Address           647511 non-null  object
#  3   Latitude          647511 non-null  float64
#  4   Longitude         647511 non-null  float64
#  5   SO2               647511 non-null  float64
#  6   NO2               647511 non-null  float64
#  7   O3                647511 non-null  float64
#  8   CO                647511 non-null  float64
#  9   PM10              647511 non-null  float64
#  10  PM2.5             647511 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(1)
# memory usage: 54.3+ MB

# %%
df.head()
# Out:
#      Measurement date  Station code  \
# 0 2017-01-01 00:00:00           101
# 1 2017-01-01 01:00:00           101
# 2 2017-01-01 02:00:00           101
# 3 2017-01-01 03:00:00           101
# 4 2017-01-01 04:00:00           101
#
#                                              Address   Latitude   Longitude  \
# 0  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 1  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 2  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 3  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 4  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
#
#      SO2    NO2     O3   CO  PM10  PM2.5
# 0  0.004  0.059  0.002  1.2  73.0   57.0
# 1  0.004  0.058  0.002  1.2  71.0   59.0
# 2  0.004  0.056  0.002  1.2  70.0   59.0
# 3  0.004  0.056  0.002  1.2  70.0   58.0
# 4  0.003  0.051  0.002  1.2  69.0   61.0

# %%
df.isna().sum()
# Out:
# Measurement date    0
# Station code        0
# Address             0
# Latitude            0
# Longitude           0
# SO2                 0
# NO2                 0
# O3                  0
# CO                  0
# PM10                0
# PM2.5               0
# dtype: int64

# %%
count = df.size
count
# Out:
# 7122621

# %%
countdrop = df.dropna().size
countdrop
# Out:
# 7122621

# %%
pollutant = ['SO2','NO2','O3','CO','PM10','PM2.5']
df[pollutant] = df[pollutant][df[pollutant]>0]
df = df.dropna()
df
# Out:
# C:\Users\김동민\AppData\Local\Temp\ipykernel_2064\482512241.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[pollutant] = df[pollutant][df[pollutant]>0]
#           Measurement date  Station code  \
# 0      2017-01-01 00:00:00           101
# 1      2017-01-01 01:00:00           101
# 2      2017-01-01 02:00:00           101
# 3      2017-01-01 03:00:00           101
# 4      2017-01-01 04:00:00           101
# ...                    ...           ...
# 647506 2019-12-31 19:00:00           125
# 647507 2019-12-31 20:00:00           125
# 647508 2019-12-31 21:00:00           125
# 647509 2019-12-31 22:00:00           125
# 647510 2019-12-31 23:00:00           125
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 632447 entries, 0 to 647510
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Measurement date  632447 non-null  datetime64[ns]
#  1   Station code      632447 non-null  int64
#  2   Address           632447 non-null  object
#  3   Latitude          632447 non-null  float64
#  4   Longitude         632447 non-null  float64
#  5   SO2               632447 non-null  float64
#  6   NO2               632447 non-null  float64
#  7   O3                632447 non-null  float64
#  8   CO                632447 non-null  float64
#  9   PM10              632447 non-null  float64
#  10  PM2.5             632447 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1), object(1)
# memory usage: 57.9+ MB

# %%
df.shape
# Out:
# (632447, 11)

# %%
duplicates = df.duplicated()
print(df[duplicates])
# Out:
# Empty DataFrame
# Columns: [Measurement date, Station code, Address, Latitude, Longitude, SO2, NO2, O3, CO, PM10, PM2.5]
# Index: []

# %%
excel_file_path = r'C:\Users\김동민\Desktop\datasets\airpollution\AirPollutionSeoul\Measurement_summary_filtered.xlsx'
df.to_excel(excel_file_path, index=False)
print(f'DataFrame saved to {excel_file_path}')
# Out:
# DataFrame saved to C:\Users\김동민\Desktop\datasets\airpollution\AirPollutionSeoul\Measurement_summary_filtered.xlsx
